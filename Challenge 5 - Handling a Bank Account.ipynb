# %%
class Account:
    def __init__(self):
        self.balance=0
        self.interestRate = 0.05
        print('***Your Account is Created***.')
    def deposit(self):
        amount=float(input('\n\nEnter the amount to deposit:'))
        self.balance+=amount
        print('Your New Balance *********** = ₹%.2f' %self.balance)
    def withdraw(self):
        amount=float(input('\n\nEnter the amount to withdraw:'))
        if(amount>self.balance):
            print('\n\nInsufficient Balance!')
        else:
            self.balance-=amount
            print('\n\nYour Remaining Balance *********** = ₹%.2f' %self.balance)
    def enquiry(self):
        print('\nYour Balance ***********= ₹%.2f' %self.balance)
    def addInterest(self):
        self.balance += self.balance * self.interestRate
        print('\n\nYour New Balance with Interest ***********: ₹%.2f' % self.balance)

account= Account()
account.deposit()
account.withdraw()
account.enquiry()
account.addInterest()
# Out:
# ***Your Account is Created***.
# Enter the amount to deposit: 2000
# Your New Balance *********** = ₹2000.00
# Enter the amount to withdraw: 500
# Your Remaining Balance *********** = ₹1500.00
#
# Your Balance ***********= ₹1500.00
#
#
# Your New Balance with Interest ***********: ₹1575.00
